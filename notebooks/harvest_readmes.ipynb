# %%
import requests
from datetime import datetime, timedelta
import math
from ghapi.all import GhApi

# %%
import base64
import json

# %%
github_key = None
with open(".env", "r") as f:
    lines = f.readlines()

    for line in lines:
        if line.startswith("GITHUB_TOKEN"):
            parts = line.split("=")[1:]
            github_key = "=".join(parts).strip().strip('"')
            continue

assert github_key is not None, "Github key not found in .env file"
github = GhApi(owner='azure',token=github_key)

# %%
# #### print to see option
# # api.repos
# azure_sdk_readmes = []
# sdk_list = api.repos.get_content(owner='azure', repo='azure-sdk-for-net', path='sdk', ref='main')

# for subdirs in sdk_list:
#     print(subdirs.path)
#     sdks = api.repos.get_content(owner='azure', repo='azure-sdk-for-net', path=subdirs.path, ref='main')

#     for sdk in sdks:
#         sdk_contents = api.repos.get_content(owner='azure', repo='azure-sdk-for-net', path=sdk.path, ref='main')
#         # print (sdk_contents)
#         # print ("deeznuts!")
#         # print(sdk.path)
#         # readme = api.repos.get_readme(owner='azure', repo='azure-sdk-for-net', path=sdk.path, ref='main')
#         # print (readme)
#         for content in sdk_contents:
#             if isinstance(content, str):
#                 continue
#             if content.type == "file" and content.name == 'README.md':
#                 # print("found one!")
#                 # print(content)
#                 azure_sdk_readmes.append(content)
#                 break

# len(azure_sdk_readmes)

# %%
def get_azure_sdk_readmes(owner, repo):
    azure_sdk_readmes = []
    sdk_list = github.repos.get_content(owner=owner, repo=repo, path='sdk', ref='main')

    for subdirs in sdk_list:
        if isinstance(subdirs, str):
            continue
        sdks = github.repos.get_content(owner=owner, repo=repo, path=subdirs.path, ref='main')

        for sdk in sdks:
            if isinstance(sdk, str):
                continue
            if sdk.type == "file" and sdk.name == 'README.md':
                    azure_sdk_readmes.append(sdk)
                    break
            sdk_contents = github.repos.get_content(owner=owner, repo=repo, path=sdk.path, ref='main')

            for content in sdk_contents:
                if isinstance(content, str):
                    continue
                if content.type == "file" and content.name == 'README.md':
                    azure_sdk_readmes.append(content)
                    break

    return azure_sdk_readmes

# %%
def get_azure_sdk_apis (owner, repo):
    azure_sdk_apis = []
    sdk_list = github.repos.get_content(owner=owner, repo=repo, path='sdk', ref='main')

    for subdirs in sdk_list:
        if isinstance(subdirs, str):
            continue
        sdks = github.repos.get_content(owner=owner, repo=repo, path=subdirs.path, ref='main')

        for sdk in sdks:
            if isinstance(sdk, str):
                continue
            sdk_contents = github.repos.get_content(owner=owner, repo=repo, path=sdk.path, ref='main')
            for content in sdk_contents:
                if isinstance(content, str):
                    continue
                if content.type == "dir" and content.name == 'api':
                    api_contents = github.repos.get_content(owner=owner, repo=repo, path=content.path, ref='main')
                    for files in api_contents:
                        if files.type == "file":
                            azure_sdk_apis.append(files)
                            print(files)
                            break
                

    return azure_sdk_apis

# %%
def getREADMEContent(repos, language, api=github):
    #### Functin that takes in list of README URLS and returns an object of the form:
    #### [{"url_to_readme":url,"content":content,"repo_name":repo_name,"org_name":org_name,"link_to_repo":repo_link, "repo_ghapi_response":repo_ghapi_response},...]
    #### The line used to get README content from ghapi JSON response is `content = base64.b64decode(api.repos.get_readme(repos[10].name)['content']).decode('utf-8')`
    #### The incoming list is a list of objects from a call like api.repos.get_readme(repos[10].name)
    #### where repos is the ghapi response for a call like api.repos.list_for_org(org='microsoft',per_page=100,page=1)
    results = []
    for repoJSON in repos:
        # print(repoJSON.path)
        try:
            newObject = {
                # 'README_text': base64.b64decode(api.repos.get_readme(repoJSON.name)['content']).decode('utf-8'),
                'README_text': requests.get(repoJSON.download_url).text,
                'repo_name': (repoJSON.path.replace('sdk/', '')).replace('/README.md', ''),
                # 'org_name': repoJSON.owner.login,
                # 'org_repo': repoJSON.owner.login + '/' + repoJSON.name,
                # 'platform_org_repo': platform + '+' + repoJSON.owner.login + '/' + repoJSON.name,
                'link_to_repo': repoJSON.html_url.replace('/README.md', ''),
                # "repo_api_response": dict(repoJSON), ### The incoming dict is a class fastcore so this fail!
                # "platform": platform,
                # "archived": repoJSON.archived,
                # "description": repoJSON.description,
                # "fork": repoJSON.fork,
                # "forks_count": repoJSON.forks_count,
                # "is_template": repoJSON.is_template,
                "language": language,
                # "languages_url": repoJSON.languages_url,
                # "license": repoJSON.license.spdx_id,
                # "open_issues_count": repoJSON.open_issues_count,
                # "open_issues": repoJSON.open_issues,
                # "pushed_at": repoJSON.pushed_at,
                # "stargazers_count": repoJSON.stargazers_count,
                # "watchers_count": repoJSON.watchers_count,
                # "size": repoJSON.size,
                # "default_branch": repoJSON.default_branch,
                # "visibility": repoJSON.visibility,
                # "topics": repoJSON.topics
                # "updated_at": repoJSON.updated_at,

            }
            ##results[platform + "+" + repoJSON.owner.login +  "+" + repoJSON.name] = newObject
            # print(newObject)
            results.append(newObject)
        except Exception as err:
            print(f'Error occurred while processing {repoJSON}: {err}')

    return results

# %%
# api.repos

# %%
# all_data = getXNumberReposSinceDateInGivenOrg(orgs=['Azure','Azure-Samples','MicrosoftDocs'],numberOfReposToSearchThrough=20000,per_page=100,since='2022-06-07T22:49:39Z',platform='github',output_file_path="../data/READMEs/azure_past_365days.json")

# %%
# output_file_path="../data/READMEs/azure_sdk_readme_net_list.json"

# net_data = get_azure_sdk_readmes(owner='Azure', repo='azure-sdk-for-net')
# JSON_readme_list = getREADMEContent(net_data, ["C#", ".NET"])
# with open(output_file_path, "w") as outfile:
#     json.dump(JSON_readme_list, outfile)

# output_file_path="../data/READMEs/azure_sdk_readme_java_list.json"
# java_data = get_azure_sdk_readmes(owner='Azure', repo='azure-sdk-for-java')
# JSON_readme_list = getREADMEContent(java_data, ["Java"])
# with open(output_file_path, "a") as outfile:
#     json.dump(JSON_readme_list, outfile)

# output_file_path="../data/READMEs/azure_sdk_readme_javascript_list.json"
# javascript_data = get_azure_sdk_readmes(owner='Azure', repo='azure-sdk-for-js')
# JSON_readme_list = getREADMEContent(javascript_data, ["JavaScript"])
# with open(output_file_path, "a") as outfile:
#     json.dump(JSON_readme_list, outfile)

# output_file_path="../data/READMEs/azure_sdk_readme_python_list.json"
# python_data = get_azure_sdk_readmes(owner='Azure', repo='azure-sdk-for-python')
# JSON_readme_list = getREADMEContent(python_data, ["Python"])
# with open(output_file_path, "a") as outfile:
#     json.dump(JSON_readme_list, outfile)

# output_file_path="../data/READMEs/azure_sdk_readme_rust_list.json"
# rust_data = get_azure_sdk_readmes(owner='Azure', repo='azure-sdk-for-rust')
# JSON_readme_list = getREADMEContent(rust_data, ["Rust"])
# with open(output_file_path, "a") as outfile:
#     json.dump(JSON_readme_list, outfile)

output_file_path="../data/READMEs/azure_sdk_api_net_list.json"    
net_data = get_azure_sdk_apis(owner='Azure', repo='azure-sdk-for-net')
JSON_readme_list = getREADMEContent(net_data, ["C#", ".NET"])
with open(output_file_path, "a") as outfile:
    json.dump(JSON_readme_list, outfile)
    
print("finished writing to file: ",output_file_path)
# Out:
# {'name': 'Azure.ResourceManager.Advisor.netstandard2.0.cs', 'path': 'sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs', 'sha': '72898d70369390fc4e542a3a3b70d07eb0f7fe72', 'size': 38548, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/72898d70369390fc4e542a3a3b70d07eb0f7fe72', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/72898d70369390fc4e542a3a3b70d07eb0f7fe72', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/advisor/Azure.ResourceManager.Advisor/api/Azure.ResourceManager.Advisor.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs', 'path': 'sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs', 'sha': 'e3883888b6d59953eef850acf3536ed825eb08cd', 'size': 55529, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/e3883888b6d59953eef850acf3536ed825eb08cd', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/e3883888b6d59953eef850acf3536ed825eb08cd', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/agrifood/Azure.ResourceManager.AgFoodPlatform/api/Azure.ResourceManager.AgFoodPlatform.netstandard2.0.cs'}}
# {'name': 'Azure.Verticals.AgriFood.Farming.netstandard2.0.cs', 'path': 'sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs', 'sha': 'dd157e6434a7149f44990f67b87140babf7453a2', 'size': 166550, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dd157e6434a7149f44990f67b87140babf7453a2', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dd157e6434a7149f44990f67b87140babf7453a2', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/agrifood/Azure.Verticals.AgriFood.Farming/api/Azure.Verticals.AgriFood.Farming.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.AlertsManagement.netstandard2.0.cs', 'path': 'sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs', 'sha': '57dfd681cd2b2e0a757fc73818ff34f42c712491', 'size': 90442, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/57dfd681cd2b2e0a757fc73818ff34f42c712491', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/57dfd681cd2b2e0a757fc73818ff34f42c712491', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/alertsmanagement/Azure.ResourceManager.AlertsManagement/api/Azure.ResourceManager.AlertsManagement.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.Analysis.netstandard2.0.cs', 'path': 'sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs', 'sha': '37a44d9030e897f6818ca1e9d7488a4ee6fb4ea4', 'size': 32183, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/37a44d9030e897f6818ca1e9d7488a4ee6fb4ea4', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/37a44d9030e897f6818ca1e9d7488a4ee6fb4ea4', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/analysisservices/Azure.ResourceManager.Analysis/api/Azure.ResourceManager.Analysis.netstandard2.0.cs'}}
# {'name': 'Azure.AI.AnomalyDetector.netstandard2.0.cs', 'path': 'sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs', 'sha': 'f68b3c28571a2a9da2c9c7d15380cbdf3400f22d', 'size': 35982, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/f68b3c28571a2a9da2c9c7d15380cbdf3400f22d', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/f68b3c28571a2a9da2c9c7d15380cbdf3400f22d', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/anomalydetector/Azure.AI.AnomalyDetector/api/Azure.AI.AnomalyDetector.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.ApiManagement.netstandard2.0.cs', 'path': 'sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs', 'sha': 'bcaf907bf1bf91ffec94d10124bcb695b7051638', 'size': 652939, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/bcaf907bf1bf91ffec94d10124bcb695b7051638', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/bcaf907bf1bf91ffec94d10124bcb695b7051638', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/apimanagement/Azure.ResourceManager.ApiManagement/api/Azure.ResourceManager.ApiManagement.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs', 'path': 'sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs', 'sha': 'dd0521621b220b50fcb8aa7ae5a1abfc79fc35dc', 'size': 53223, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dd0521621b220b50fcb8aa7ae5a1abfc79fc35dc', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dd0521621b220b50fcb8aa7ae5a1abfc79fc35dc', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appcomplianceautomation/Azure.ResourceManager.AppComplianceAutomation/api/Azure.ResourceManager.AppComplianceAutomation.netstandard2.0.cs'}}
# {'name': 'Azure.Data.AppConfiguration.netstandard2.0.cs', 'path': 'sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs', 'sha': 'c2230082aebf82fb1bd84b3ca519660fd2e132d8', 'size': 30389, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/c2230082aebf82fb1bd84b3ca519660fd2e132d8', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/c2230082aebf82fb1bd84b3ca519660fd2e132d8', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appconfiguration/Azure.Data.AppConfiguration/api/Azure.Data.AppConfiguration.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.AppConfiguration.netstandard2.0.cs', 'path': 'sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs', 'sha': '645b9e8055a0a95e34b15220cd56b9816116802e', 'size': 64891, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/645b9e8055a0a95e34b15220cd56b9816116802e', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/645b9e8055a0a95e34b15220cd56b9816116802e', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appconfiguration/Azure.ResourceManager.AppConfiguration/api/Azure.ResourceManager.AppConfiguration.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs', 'path': 'sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs', 'sha': 'de89c05da80c7eb9d78a7b5a4dd92ff1bc278f94', 'size': 151767, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/de89c05da80c7eb9d78a7b5a4dd92ff1bc278f94', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/de89c05da80c7eb9d78a7b5a4dd92ff1bc278f94', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/applicationinsights/Azure.ResourceManager.ApplicationInsights/api/Azure.ResourceManager.ApplicationInsights.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.AppPlatform.netstandard2.0.cs', 'path': 'sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs', 'sha': '3828ee1101e190bd6f336cc86a483bde1c44e4ae', 'size': 313798, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/3828ee1101e190bd6f336cc86a483bde1c44e4ae', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/3828ee1101e190bd6f336cc86a483bde1c44e4ae', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/appplatform/Azure.ResourceManager.AppPlatform/api/Azure.ResourceManager.AppPlatform.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.ArcScVmm.netstandard2.0.cs', 'path': 'sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs', 'sha': '26b0373cb8188c1d8693aefce77151299eadd012', 'size': 98445, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/26b0373cb8188c1d8693aefce77151299eadd012', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/26b0373cb8188c1d8693aefce77151299eadd012', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/arc-scvmm/Azure.ResourceManager.ArcScVmm/api/Azure.ResourceManager.ArcScVmm.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.Attestation.netstandard2.0.cs', 'path': 'sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs', 'sha': '72f9659a5ecd8b0e8b461de78b28158f3bd059fd', 'size': 32958, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/72f9659a5ecd8b0e8b461de78b28158f3bd059fd', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/72f9659a5ecd8b0e8b461de78b28158f3bd059fd', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/attestation/Azure.ResourceManager.Attestation/api/Azure.ResourceManager.Attestation.netstandard2.0.cs'}}
# {'name': 'Azure.Security.Attestation.netstandard2.0.cs', 'path': 'sdk/attestation/Azure.Security.Attestation/api/Azure.Security.Attestation.netstandard2.0.cs', 'sha': '823be79786f8315687dc99cb7905c60d817d02d4', 'size': 28274, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk
netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/b1c4dbea31803edf6d178b2f024971e2a5742c9b', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/changeanalysis/Azure.ResourceManager.ChangeAnalysis/api/Azure.ResourceManager.ChangeAnalysis.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.Chaos.netstandard2.0.cs', 'path': 'sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs', 'sha': 'e78b952137782da83609152560c11eefe6ae8657', 'size': 57403, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/e78b952137782da83609152560c11eefe6ae8657', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/e78b952137782da83609152560c11eefe6ae8657', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/chaos/Azure.ResourceManager.Chaos/api/Azure.ResourceManager.Chaos.netstandard2.0.cs'}}
# {'name': 'Azure.AI.Language.Conversations.netstandard2.0.cs', 'path': 'sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs', 'sha': 'cf8f60702e6f9829f22044de04e12249e10012ea', 'size': 17375, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/cf8f60702e6f9829f22044de04e12249e10012ea', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/cf8f60702e6f9829f22044de04e12249e10012ea', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitivelanguage/Azure.AI.Language.Conversations/api/Azure.AI.Language.Conversations.netstandard2.0.cs'}}
# {'name': 'Azure.AI.Language.QuestionAnswering.netstandard2.0.cs', 'path': 'sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs', 'sha': '75a69638533bc44d364af23be6d6b5cc6c1f6391', 'size': 27920, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/75a69638533bc44d364af23be6d6b5cc6c1f6391', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/75a69638533bc44d364af23be6d6b5cc6c1f6391', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitivelanguage/Azure.AI.Language.QuestionAnswering/api/Azure.AI.Language.QuestionAnswering.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.CognitiveServices.netstandard2.0.cs', 'path': 'sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs', 'sha': '95a4d185ca176d6348fa09fb794b701739d9794f', 'size': 139243, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/95a4d185ca176d6348fa09fb794b701739d9794f', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/95a4d185ca176d6348fa09fb794b701739d9794f', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/cognitiveservices/Azure.ResourceManager.CognitiveServices/api/Azure.ResourceManager.CognitiveServices.netstandard2.0.cs'}}
# {'name': 'Azure.Communication.AlphaIds.netstandard2.0.cs', 'path': 'sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs', 'sha': 'dcbec23ea925e5f0edbd1f3e5f2796427e4014fe', 'size': 2262, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dcbec23ea925e5f0edbd1f3e5f2796427e4014fe', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/dcbec23ea925e5f0edbd1f3e5f2796427e4014fe', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.AlphaIds/api/Azure.Communication.AlphaIds.netstandard2.0.cs'}}
# {'name': 'Azure.Communication.CallAutomation.netstandard2.0.cs', 'path': 'sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs', 'sha': '936b2145be45804f692bf1ba0060b13168bf60e0', 'size': 112867, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/936b2145be45804f692bf1ba0060b13168bf60e0', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/936b2145be45804f692bf1ba0060b13168bf60e0', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.CallAutomation/api/Azure.Communication.CallAutomation.netstandard2.0.cs'}}
# {'name': 'Azure.Communication.CallingServer.netstandard2.0.cs', 'path': 'sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs', 'sha': '91ab66f5b0646a30528857ed87e1ae36b0e54c16', 'size': 69163, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/91ab66f5b0646a30528857ed87e1ae36b0e54c16', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/91ab66f5b0646a30528857ed87e1ae36b0e54c16', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/communication/Azure.Communication.CallingServer/api/Azure.Communication.CallingServer.netstandard2.0.cs'}}
# ...
# {'name': 'Azure.ResourceManager.VoiceServices.netstandard2.0.cs', 'path': 'sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs', 'sha': '75a935a7a07c977b602db91ebc85ae8e28ca2f80', 'size': 44282, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/75a935a7a07c977b602db91ebc85ae8e28ca2f80', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/75a935a7a07c977b602db91ebc85ae8e28ca2f80', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/voiceservices/Azure.ResourceManager.VoiceServices/api/Azure.ResourceManager.VoiceServices.netstandard2.0.cs'}}
# {'name': 'Azure.Messaging.WebPubSub.Client.netstandard2.0.cs', 'path': 'sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs', 'sha': '0110be1c4dc3d2ee7c5feedb891098a26717a567', 'size': 13691, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/0110be1c4dc3d2ee7c5feedb891098a26717a567', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/0110be1c4dc3d2ee7c5feedb891098a26717a567', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.Messaging.WebPubSub.Client/api/Azure.Messaging.WebPubSub.Client.netstandard2.0.cs'}}
# {'name': 'Azure.Messaging.WebPubSub.netstandard2.0.cs', 'path': 'sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs', 'sha': '903575a7a73ff54d091749aefec493c87233bae9', 'size': 16801, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/903575a7a73ff54d091749aefec493c87233bae9', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/903575a7a73ff54d091749aefec493c87233bae9', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.Messaging.WebPubSub/api/Azure.Messaging.WebPubSub.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.WebPubSub.netstandard2.0.cs', 'path': 'sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs', 'sha': 'b8d72f595972e495ed4cd977b6d6f120454e7287', 'size': 66795, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/b8d72f595972e495ed4cd977b6d6f120454e7287', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/b8d72f595972e495ed4cd977b6d6f120454e7287', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Azure.ResourceManager.WebPubSub/api/Azure.ResourceManager.WebPubSub.netstandard2.0.cs'}}
# {'name': 'Microsoft.Azure.Functions.Worker.Extensions.WebPubSub.netstandard2.0.cs', 'path': 'sdk/webpubsub/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub/api/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub.netstandard2.0.cs', 'sha': 'ee553b8d299cdc6ea3cdbd1cf69ca35c1e30f7e2', 'size': 19051, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/webpubsub/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub/api/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/webpubsub/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub/api/Microsoft.Azure.Functions.Worker.Extensions.WebPubSub.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/ee553b8d299cdc6ea3cdbd1cf69ca35c1e30f7e2', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk
 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/websites/Azure.ResourceManager.AppService/api/Azure.ResourceManager.AppService.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/websites/Azure.ResourceManager.AppService/api/Azure.ResourceManager.AppService.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/a38895aa500269e3f818a9d709fc435efa5a646f', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/websites/Azure.ResourceManager.AppService/api/Azure.ResourceManager.AppService.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/websites/Azure.ResourceManager.AppService/api/Azure.ResourceManager.AppService.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/a38895aa500269e3f818a9d709fc435efa5a646f', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/websites/Azure.ResourceManager.AppService/api/Azure.ResourceManager.AppService.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs', 'path': 'sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs', 'sha': '5644516a0df822e969179d538d805bf726ca4030', 'size': 16240, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/5644516a0df822e969179d538d805bf726ca4030', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/5644516a0df822e969179d538d805bf726ca4030', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/workloadmonitor/Azure.ResourceManager.WorkloadMonitor/api/Azure.ResourceManager.WorkloadMonitor.netstandard2.0.cs'}}
# {'name': 'Azure.ResourceManager.Workloads.netstandard2.0.cs', 'path': 'sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs', 'sha': 'c0267811d09828c785f4f33f2b170bd53934c276', 'size': 157284, 'url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs?ref=main', 'html_url': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs', 'git_url': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/c0267811d09828c785f4f33f2b170bd53934c276', 'download_url': 'https://raw.githubusercontent.com/Azure/azure-sdk-for-net/main/sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/Azure/azure-sdk-for-net/contents/sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs?ref=main', 'git': 'https://api.github.com/repos/Azure/azure-sdk-for-net/git/blobs/c0267811d09828c785f4f33f2b170bd53934c276', 'html': 'https://github.com/Azure/azure-sdk-for-net/blob/main/sdk/workloads/Azure.ResourceManager.Workloads/api/Azure.ResourceManager.Workloads.netstandard2.0.cs'}}
# finished writing to file:  ../data/READMEs/azure_sdk_api_net_list.json

# %%
len(net_data)
print(net_data[4])
# JSON_readme_list = getREADMEContent(net_data, ["C#", ".NET"])
# len(JSON_readme_list)
# print(JSON_readme_list[0])

# %%
# def load_json_from_file(file_path):
#     with open(file_path, "r") as infile:
#         data = json.load(infile)
#     return data

# %%
# data = load_json_from_file("../data/READMEs/azure_sdk_readme_list.json")

# %%
# data

# %%
# len(data)

# %%
# data[-6:]
